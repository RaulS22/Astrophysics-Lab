# %% [markdown]
# # III: Calibration and Background
# # Notebook with some basic data reduction and analysis with python

# %% [markdown]
# ## First, import necessary libraries

# %%
import numpy as np
import scipy
import matplotlib.pyplot as plt
from astropy.io import fits

# %% [markdown]
# ## Let's open fits files

# %% [markdown]
# **Green**

# %%
dir = '/content/sample_data/' # directory where fits files are found
file10= dir+'sheliak_2024-09-23_19-25-45_Green_0301.fits' #file names
science0 = fits.getdata(file10)  # data matrices
file20= dir+'master_bias.fits' #file names
master_bias = fits.getdata(file20)  # data matrices
file30= dir+'master_flat_green.fits' #file names
master_flat = fits.getdata(file30)  # data matrices

dir = '/content/sample_data/' # directory where fits files are found
file11= dir+'sheliak_2024-09-23_19-25-59_Green_0302.fits' #file names
science1 = fits.getdata(file11)  # data matrices
file21= dir+'master_bias.fits' #file names
master_bias = fits.getdata(file21)  # data matrices
file31= dir+'master_flat_green.fits' #file names
master_flat = fits.getdata(file31)  # data matrices

dir = '/content/sample_data/' # directory where fits files are found
file12= dir+'sheliak_2024-09-23_19-26-02_Green_0303.fits' #file names
science2 = fits.getdata(file12)  # data matrices
file22= dir+'master_bias.fits' #file names
master_bias = fits.getdata(file22)  # data matrices
file32= dir+'master_flat_green.fits' #file names
master_flat = fits.getdata(file32)  # data matrices

dir = '/content/sample_data/' # directory where fits files are found
file13= dir+'sheliak_2024-09-23_19-26-05_Green_0304.fits' #file names
science3 = fits.getdata(file13)  # data matrices
file23= dir+'master_bias.fits' #file names
master_bias = fits.getdata(file23)  # data matrices
file33= dir+'master_flat_green.fits' #file names
master_flat = fits.getdata(file33)  # data matrices

dir = '/content/sample_data/' # directory where fits files are found
file14= dir+'sheliak_2024-09-23_19-26-07_Green_0305.fits' #file names
science4 = fits.getdata(file14)  # data matrices
file24= dir+'master_bias.fits' #file names
master_bias = fits.getdata(file24)  # data matrices
file34= dir+'master_flat_green.fits' #file names
master_flat = fits.getdata(file34)  # data matrices

dir = '/content/sample_data/' # directory where fits files are found
file15= dir+'sheliak_2024-09-23_19-26-10_Green_0306.fits' #file names
science5 = fits.getdata(file15)  # data matrices
file25= dir+'master_bias.fits' #file names
master_bias = fits.getdata(file25)  # data matrices
file35= dir+'master_flat_green.fits' #file names
master_flat = fits.getdata(file35)  # data matrices

dir = '/content/sample_data/' # directory where fits files are found
file16= dir+'sheliak_2024-09-23_19-26-13_Green_0307.fits' #file names
science6 = fits.getdata(file16)  # data matrices
file26= dir+'master_bias.fits' #file names
master_bias = fits.getdata(file26)  # data matrices
file36= dir+'master_flat_green.fits' #file names
master_flat = fits.getdata(file36)  # data matrices

dir = '/content/sample_data/' # directory where fits files are found
file17= dir+'sheliak_2024-09-23_19-26-16_Green_0308.fits' #file names
science7 = fits.getdata(file17)  # data matrices
file27= dir+'master_bias.fits' #file names
master_bias = fits.getdata(file27)  # data matrices
file37= dir+'master_flat_green.fits' #file names
master_flat = fits.getdata(file37)  # data matrices

dir = '/content/sample_data/' # directory where fits files are found
file18= dir+'sheliak_2024-09-23_19-26-18_Green_0309.fits' #file names
science8 = fits.getdata(file18)  # data matrices
file28= dir+'master_bias.fits' #file names
master_bias = fits.getdata(file28)  # data matrices
file38= dir+'master_flat_green.fits' #file names
master_flat = fits.getdata(file38)  # data matrices

dir = '/content/sample_data/' # directory where fits files are found
file19= dir+'sheliak_2024-09-23_19-26-21_Green_0310.fits' #file names
science9 = fits.getdata(file19)  # data matrices
file29= dir+'master_bias.fits' #file names
master_bias = fits.getdata(file29)  # data matrices
file39= dir+'master_flat_green.fits' #file names
master_flat = fits.getdata(file39)  # data matrices

file110= dir+'sheliak_2024-09-23_19-26-24_Green_0311.fits' #file names
science10 = fits.getdata(file110)  # data matrices
file210= dir+'master_bias.fits' #file names
master_bias = fits.getdata(file210)  # data matrices
file310= dir+'master_flat_green.fits' #file names
master_flat = fits.getdata(file310)  # data matrices

# %% [markdown]
# ## Calibrate the science file

# %%
##301

science_calibrated0=(science0-master_bias)/master_flat
#This example needs a mask!
mask=np.zeros(np.shape(science_calibrated0))
for i in range(len(science_calibrated0)):
  for j in range(len(science_calibrated0[i])):
    if master_flat[i][j]<0.2:
      science_calibrated0[i][j]=0
      mask[i][j]=1
mask=mask.astype(bool)

# Criar um objeto FITS a partir dos dados
hdu = fits.PrimaryHDU(science_calibrated0)

# Criar um HDUList (caso queira adicionar extensões)
hdul = fits.HDUList([hdu])

# Salvar a imagem no arquivo .fits
hdul.writeto('sheliak_green_301.fits', overwrite=True)

##302

science_calibrated1=(science1-master_bias)/master_flat
#This example needs a mask!
mask=np.zeros(np.shape(science_calibrated1))
for i in range(len(science_calibrated1)):
  for j in range(len(science_calibrated1[i])):
    if master_flat[i][j]<0.2:
      science_calibrated1[i][j]=0
      mask[i][j]=1
mask=mask.astype(bool)

# Criar um objeto FITS a partir dos dados
hdu = fits.PrimaryHDU(science_calibrated1)

# Criar um HDUList (caso queira adicionar extensões)
hdul = fits.HDUList([hdu])

# Salvar a imagem no arquivo .fits
hdul.writeto('sheliak_green_302.fits', overwrite=True)

##303

science_calibrated2=(science2-master_bias)/master_flat
#This example needs a mask!
mask=np.zeros(np.shape(science_calibrated2))
for i in range(len(science_calibrated2)):
  for j in range(len(science_calibrated2[i])):
    if master_flat[i][j]<0.2:
      science_calibrated2[i][j]=0
      mask[i][j]=1
mask=mask.astype(bool)

# Criar um objeto FITS a partir dos dados
hdu = fits.PrimaryHDU(science_calibrated2)

# Criar um HDUList (caso queira adicionar extensões)
hdul = fits.HDUList([hdu])

# Salvar a imagem no arquivo .fits
hdul.writeto('sheliak_green_303.fits', overwrite=True)

##304

science_calibrated3=(science3-master_bias)/master_flat
#This example needs a mask!
mask=np.zeros(np.shape(science_calibrated3))
for i in range(len(science_calibrated3)):
  for j in range(len(science_calibrated3[i])):
    if master_flat[i][j]<0.2:
      science_calibrated3[i][j]=0
      mask[i][j]=1
mask=mask.astype(bool)

# Criar um objeto FITS a partir dos dados
hdu = fits.PrimaryHDU(science_calibrated3)

# Criar um HDUList (caso queira adicionar extensões)
hdul = fits.HDUList([hdu])

# Salvar a imagem no arquivo .fits
hdul.writeto('sheliak_green_304.fits', overwrite=True)

##305

science_calibrated4=(science4-master_bias)/master_flat
#This example needs a mask!
mask=np.zeros(np.shape(science_calibrated4))
for i in range(len(science_calibrated4)):
  for j in range(len(science_calibrated4[i])):
    if master_flat[i][j]<0.2:
      science_calibrated4[i][j]=0
      mask[i][j]=1
mask=mask.astype(bool)

# Criar um objeto FITS a partir dos dados
hdu = fits.PrimaryHDU(science_calibrated4)

# Criar um HDUList (caso queira adicionar extensões)
hdul = fits.HDUList([hdu])

# Salvar a imagem no arquivo .fits
hdul.writeto('sheliak_green_305.fits', overwrite=True)

##306

science_calibrated5=(science5-master_bias)/master_flat
#This example needs a mask!
mask=np.zeros(np.shape(science_calibrated5))
for i in range(len(science_calibrated5)):
  for j in range(len(science_calibrated5[i])):
    if master_flat[i][j]<0.2:
      science_calibrated5[i][j]=0
      mask[i][j]=1
mask=mask.astype(bool)

# Criar um objeto FITS a partir dos dados
hdu = fits.PrimaryHDU(science_calibrated5)

# Criar um HDUList (caso queira adicionar extensões)
hdul = fits.HDUList([hdu])

# Salvar a imagem no arquivo .fits
hdul.writeto('sheliak_green_306.fits', overwrite=True)

##307

science_calibrated6=(science6-master_bias)/master_flat
#This example needs a mask!
mask=np.zeros(np.shape(science_calibrated6))
for i in range(len(science_calibrated6)):
  for j in range(len(science_calibrated6[i])):
    if master_flat[i][j]<0.2:
      science_calibrated6[i][j]=0
      mask[i][j]=1
mask=mask.astype(bool)

# Criar um objeto FITS a partir dos dados
hdu = fits.PrimaryHDU(science_calibrated6)

# Criar um HDUList (caso queira adicionar extensões)
hdul = fits.HDUList([hdu])

# Salvar a imagem no arquivo .fits
hdul.writeto('sheliak_green_307.fits', overwrite=True)

##308

science_calibrated7=(science7-master_bias)/master_flat
#This example needs a mask!
mask=np.zeros(np.shape(science_calibrated7))
for i in range(len(science_calibrated7)):
  for j in range(len(science_calibrated7[i])):
    if master_flat[i][j]<0.2:
      science_calibrated7[i][j]=0
      mask[i][j]=1
mask=mask.astype(bool)

# Criar um objeto FITS a partir dos dados
hdu = fits.PrimaryHDU(science_calibrated7)

# Criar um HDUList (caso queira adicionar extensões)
hdul = fits.HDUList([hdu])

# Salvar a imagem no arquivo .fits
hdul.writeto('sheliak_green_308.fits', overwrite=True)

##309

science_calibrated8=(science8-master_bias)/master_flat
#This example needs a mask!
mask=np.zeros(np.shape(science_calibrated8))
for i in range(len(science_calibrated8)):
  for j in range(len(science_calibrated8[i])):
    if master_flat[i][j]<0.2:
      science_calibrated8[i][j]=0
      mask[i][j]=1
mask=mask.astype(bool)

# Criar um objeto FITS a partir dos dados
hdu = fits.PrimaryHDU(science_calibrated8)

# Criar um HDUList (caso queira adicionar extensões)
hdul = fits.HDUList([hdu])

# Salvar a imagem no arquivo .fits
hdul.writeto('sheliak_green_309.fits', overwrite=True)

##310

science_calibrated9=(science9-master_bias)/master_flat
#This example needs a mask!
mask=np.zeros(np.shape(science_calibrated9))
for i in range(len(science_calibrated9)):
  for j in range(len(science_calibrated9[i])):
    if master_flat[i][j]<0.2:
      science_calibrated9[i][j]=0
      mask[i][j]=1
mask=mask.astype(bool)

# Criar um objeto FITS a partir dos dados
hdu = fits.PrimaryHDU(science_calibrated9)

# Criar um HDUList (caso queira adicionar extensões)
hdul = fits.HDUList([hdu])

# Salvar a imagem no arquivo .fits
hdul.writeto('sheliak_green_310.fits', overwrite=True)

##311

science_calibrated10=(science10-master_bias)/master_flat
#This example needs a mask!
mask=np.zeros(np.shape(science_calibrated10))
for i in range(len(science_calibrated10)):
  for j in range(len(science_calibrated10[i])):
    if master_flat[i][j]<0.2:
      science_calibrated10[i][j]=0
      mask[i][j]=1
mask=mask.astype(bool)

# Criar um objeto FITS a partir dos dados
hdu = fits.PrimaryHDU(science_calibrated10)

# Criar um HDUList (caso queira adicionar extensões)
hdul = fits.HDUList([hdu])

# Salvar a imagem no arquivo .fits
hdul.writeto('sheliak_green_311.fits', overwrite=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-cb5ece3a6316> in <cell line: 3>()
#       1 ##301
#       2
# ----> 3 science_calibrated0=(science0-master_bias)/master_flat
#       4 #This example needs a mask!
#       5 mask=np.zeros(np.shape(science_calibrated0))
#
# NameError: name 'science0' is not defined

# %% [markdown]
# ***Blue***

# %%
dir = '/content/sample_data/' # directory where fits files are found
file1= dir+'vega_2024-09-23_19-23-04_Blue_0289.fits' #file names
science1 = fits.getdata(file1)  # data matrices
file2= dir+'master_bias.fits' #file names
master_bias = fits.getdata(file2)  # data matrices
file3= dir+'master_flat_blue.fits' #file names
master_flat = fits.getdata(file3)  # data matrices

file4= dir+'vega_2024-09-23_19-23-19_Blue_0290.fits' #file names
science2 = fits.getdata(file4)  # data matrices

file5= dir+'vega_2024-09-23_19-24-07_Blue_0291.fits' #file names
science3 = fits.getdata(file5)  # data matrices

file6= dir+'vega_2024-09-23_19-24-10_Blue_0292.fits' #file names
science4 = fits.getdata(file6)  # data matrices

file7= dir+'vega_2024-09-23_19-24-13_Blue_0293.fits' #file names
science5 = fits.getdata(file7)  # data matrices

file8= dir+'vega_2024-09-23_19-24-16_Blue_0294.fits' #file names
science6 = fits.getdata(file8)  # data matrices

file9= dir+'vega_2024-09-23_19-24-18_Blue_0295.fits' #file names
science7 = fits.getdata(file9)  # data matrices

file10= dir+'vega_2024-09-23_19-24-21_Blue_0296.fits' #file names
science8 = fits.getdata(file10)  # data matrices

file11= dir+'vega_2024-09-23_19-24-24_Blue_0297.fits' #file names
science9 = fits.getdata(file11)  # data matrices

file12= dir+'vega_2024-09-23_19-24-27_Blue_0298.fits' #file names
science10 = fits.getdata(file12)  # data matrices

file13= dir+'vega_2024-09-23_19-24-29_Blue_0299.fits' #file names
science11 = fits.getdata(file13)  # data matrices

file14= dir+'vega_2024-09-23_19-24-32_Blue_0300.fits' #file names
science12 = fits.getdata(file14)  # data matrices

# %%
##289

science_calibrated1=(science1-master_bias)/master_flat
#This example needs a mask!
mask=np.zeros(np.shape(science_calibrated1))
for i in range(len(science_calibrated1)):
  for j in range(len(science_calibrated1[i])):
    if master_flat[i][j]<0.2:
      science_calibrated1[i][j]=0
      mask[i][j]=1
mask=mask.astype(bool)

# Criar um objeto FITS a partir dos dados
hdu = fits.PrimaryHDU(science_calibrated1)

# Criar um HDUList (caso queira adicionar extensões)
hdul = fits.HDUList([hdu])

# Salvar a imagem no arquivo .fits
hdul.writeto('sheliak_blue_289.fits', overwrite=True)

##290

science_calibrated2=(science2-master_bias)/master_flat
#This example needs a mask!
mask=np.zeros(np.shape(science_calibrated2))
for i in range(len(science_calibrated2)):
  for j in range(len(science_calibrated2[i])):
    if master_flat[i][j]<0.2:
      science_calibrated2[i][j]=0
      mask[i][j]=1
mask=mask.astype(bool)

# Criar um objeto FITS a partir dos dados
hdu = fits.PrimaryHDU(science_calibrated2)

# Criar um HDUList (caso queira adicionar extensões)
hdul = fits.HDUList([hdu])

# Salvar a imagem no arquivo .fits
hdul.writeto('sheliak_blue_290.fits', overwrite=True)

##291

science_calibrated3=(science3-master_bias)/master_flat
#This example needs a mask!
mask=np.zeros(np.shape(science_calibrated3))
for i in range(len(science_calibrated3)):
  for j in range(len(science_calibrated3[i])):
    if master_flat[i][j]<0.2:
      science_calibrated3[i][j]=0
      mask[i][j]=1
mask=mask.astype(bool)

# Criar um objeto FITS a partir dos dados
hdu = fits.PrimaryHDU(science_calibrated3)

# Criar um HDUList (caso queira adicionar extensões)
hdul = fits.HDUList([hdu])

# Salvar a imagem no arquivo .fits
hdul.writeto('sheliak_blue_291.fits', overwrite=True)

##292

science_calibrated4=(science4-master_bias)/master_flat
#This example needs a mask!
mask=np.zeros(np.shape(science_calibrated4))
for i in range(len(science_calibrated4)):
  for j in range(len(science_calibrated4[i])):
    if master_flat[i][j]<0.2:
      science_calibrated4[i][j]=0
      mask[i][j]=1
mask=mask.astype(bool)

# Criar um objeto FITS a partir dos dados
hdu = fits.PrimaryHDU(science_calibrated4)

# Criar um HDUList (caso queira adicionar extensões)
hdul = fits.HDUList([hdu])

# Salvar a imagem no arquivo .fits
hdul.writeto('sheliak_blue_292.fits', overwrite=True)

##293

science_calibrated5=(science5-master_bias)/master_flat
#This example needs a mask!
mask=np.zeros(np.shape(science_calibrated5))
for i in range(len(science_calibrated5)):
  for j in range(len(science_calibrated5[i])):
    if master_flat[i][j]<0.2:
      science_calibrated5[i][j]=0
      mask[i][j]=1
mask=mask.astype(bool)

# Criar um objeto FITS a partir dos dados
hdu = fits.PrimaryHDU(science_calibrated5)

# Criar um HDUList (caso queira adicionar extensões)
hdul = fits.HDUList([hdu])

# Salvar a imagem no arquivo .fits
hdul.writeto('sheliak_blue_293.fits', overwrite=True)

##294


science_calibrated6=(science6-master_bias)/master_flat
#This example needs a mask!
mask=np.zeros(np.shape(science_calibrated6))
for i in range(len(science_calibrated6)):
  for j in range(len(science_calibrated6[i])):
    if master_flat[i][j]<0.2:
      science_calibrated6[i][j]=0
      mask[i][j]=1
mask=mask.astype(bool)

# Criar um objeto FITS a partir dos dados
hdu = fits.PrimaryHDU(science_calibrated6)

# Criar um HDUList (caso queira adicionar extensões)
hdul = fits.HDUList([hdu])

# Salvar a imagem no arquivo .fits
hdul.writeto('sheliak_blue_294.fits', overwrite=True)

##295

science_calibrated7=(science7-master_bias)/master_flat
#This example needs a mask!
mask=np.zeros(np.shape(science_calibrated7))
for i in range(len(science_calibrated7)):
  for j in range(len(science_calibrated7[i])):
    if master_flat[i][j]<0.2:
      science_calibrated7[i][j]=0
      mask[i][j]=1
mask=mask.astype(bool)

# Criar um objeto FITS a partir dos dados
hdu = fits.PrimaryHDU(science_calibrated7)

# Criar um HDUList (caso queira adicionar extensões)
hdul = fits.HDUList([hdu])

# Salvar a imagem no arquivo .fits
hdul.writeto('sheliak_blue_295.fits', overwrite=True)

##296

science_calibrated8=(science8-master_bias)/master_flat
#This example needs a mask!
mask=np.zeros(np.shape(science_calibrated8))
for i in range(len(science_calibrated8)):
  for j in range(len(science_calibrated8[i])):
    if master_flat[i][j]<0.2:
      science_calibrated8[i][j]=0
      mask[i][j]=1
mask=mask.astype(bool)

# Criar um objeto FITS a partir dos dados
hdu = fits.PrimaryHDU(science_calibrated8)

# Criar um HDUList (caso queira adicionar extensões)
hdul = fits.HDUList([hdu])

# Salvar a imagem no arquivo .fits
hdul.writeto('sheliak_blue_296.fits', overwrite=True)

##297

science_calibrated9=(science9-master_bias)/master_flat
#This example needs a mask!
mask=np.zeros(np.shape(science_calibrated9))
for i in range(len(science_calibrated9)):
  for j in range(len(science_calibrated9[i])):
    if master_flat[i][j]<0.2:
      science_calibrated9[i][j]=0
      mask[i][j]=1
mask=mask.astype(bool)

# Criar um objeto FITS a partir dos dados
hdu = fits.PrimaryHDU(science_calibrated9)

# Criar um HDUList (caso queira adicionar extensões)
hdul = fits.HDUList([hdu])

# Salvar a imagem no arquivo .fits
hdul.writeto('sheliak_blue_297.fits', overwrite=True)

##298

science_calibrated10=(science10-master_bias)/master_flat
#This example needs a mask!
mask=np.zeros(np.shape(science_calibrated10))
for i in range(len(science_calibrated10)):
  for j in range(len(science_calibrated10[i])):
    if master_flat[i][j]<0.2:
      science_calibrated10[i][j]=0
      mask[i][j]=1
mask=mask.astype(bool)

# Criar um objeto FITS a partir dos dados
hdu = fits.PrimaryHDU(science_calibrated10)

# Criar um HDUList (caso queira adicionar extensões)
hdul = fits.HDUList([hdu])

# Salvar a imagem no arquivo .fits
hdul.writeto('sheliak_blue_298.fits', overwrite=True)

##299

science_calibrated11=(science11-master_bias)/master_flat
#This example needs a mask!
mask=np.zeros(np.shape(science_calibrated11))
for i in range(len(science_calibrated11)):
  for j in range(len(science_calibrated11[i])):
    if master_flat[i][j]<0.2:
      science_calibrated11[i][j]=0
      mask[i][j]=1
mask=mask.astype(bool)

# Criar um objeto FITS a partir dos dados
hdu = fits.PrimaryHDU(science_calibrated11)

# Criar um HDUList (caso queira adicionar extensões)
hdul = fits.HDUList([hdu])

# Salvar a imagem no arquivo .fits
hdul.writeto('sheliak_blue_299.fits', overwrite=True)

##300

science_calibrated12=(science12-master_bias)/master_flat
#This example needs a mask!
mask=np.zeros(np.shape(science_calibrated12))
for i in range(len(science_calibrated12)):
  for j in range(len(science_calibrated12[i])):
    if master_flat[i][j]<0.2:
      science_calibrated12[i][j]=0
      mask[i][j]=1
mask=mask.astype(bool)

# Criar um objeto FITS a partir dos dados
hdu = fits.PrimaryHDU(science_calibrated12)

# Criar um HDUList (caso queira adicionar extensões)
hdul = fits.HDUList([hdu])

# Salvar a imagem no arquivo .fits
hdul.writeto('sheliak_blue_300.fits', overwrite=True)

# %% [markdown]
# **Black**

# %%
dir = '/content/sample_data/' # directory where fits files are found
#file1= dir+'vega_2024-09-23_19-20-17_black_0286.fits' #file names
#science = fits.getdata(file1)  # data matrices


file4= dir+'vega_2024-09-23_19-20-00_black_0285.fits' #file names
science2 = fits.getdata(file4)  # data matrices
file2= dir+ 'master_bias.fits' #file names
master_bias = fits.getdata(file2)  # data matrices
file3= dir+'master_flat_black.fits' #file names
master_flat = fits.getdata(file3)  # data matrices
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-03b2efa0be73> in <cell line: 7>()
#       5
#       6 file4= dir+'vega_2024-09-23_19-20-00_black_0285.fits' #file names
# ----> 7 science2 = fits.getdata(file4)  # data matrices
#       8 file2= dir+ 'master_bias.fits' #file names
#       9 master_bias = fits.getdata(file2)  # data matrices
#
# NameError: name 'fits' is not defined

# %%
##286

#science_calibrated1=(science-master_bias)/master_flat
#This example needs a mask!
#mask=np.zeros(np.shape(science_calibrated1))
#for i in range(len(science_calibrated1)):
#  for j in range(len(science_calibrated1[i])):
#    if master_flat[i][j]<0.2:
#      science_calibrated1[i][j]=0
#      mask[i][j]=1
#mask=mask.astype(bool)

# Criar um objeto FITS a partir dos dados
#hdu = fits.PrimaryHDU(science_calibrated1)

# Criar um HDUList (caso queira adicionar extensões)
#hdul = fits.HDUList([hdu])

# Salvar a imagem no arquivo .fits
#hdul.writeto('sheliak_blue_286.fits', overwrite=True)

##288

science_calibrated2=(science2-master_bias)/master_flat
#This example needs a mask!
mask=np.zeros(np.shape(science_calibrated2))
for i in range(len(science_calibrated2)):
  for j in range(len(science_calibrated2[i])):
    if master_flat[i][j]<0.2:
      science_calibrated2[i][j]=0
      mask[i][j]=1
mask=mask.astype(bool)

# Criar um objeto FITS a partir dos dados
hdu = fits.PrimaryHDU(science_calibrated2)

# Criar um HDUList (caso queira adicionar extensões)
hdul = fits.HDUList([hdu])

# Salvar a imagem no arquivo .fits
hdul.writeto('sheliak_blue_288.fits', overwrite=True)

# %% [markdown]
# **Red**

# %%
dir = '/content/sample_data/' # directory where fits files are found
file1_red = dir + 'sheliak_2024-09-23_19-26-36_Red_0312.fits'
science0_red = fits.getdata(file1_red)
file2_red = dir + 'master_bias.fits'
master_bias_red = fits.getdata(file2_red)
file3_red = dir + 'master_flat_red.fits'
master_flat_red = fits.getdata(file3_red)

file2_red = dir + 'sheliak_2024-09-23_19-26-48_Red_0313.fits'
science1_red = fits.getdata(file2_red)

file3_red = dir + 'sheliak_2024-09-23_19-26-51_Red_0314.fits'
science2_red = fits.getdata(file3_red)

file4_red = dir + 'sheliak_2024-09-23_19-26-53_Red_0315.fits'
science3_red = fits.getdata(file4_red)

file5_red = dir + 'sheliak_2024-09-23_19-26-56_Red_0316.fits'
science4_red = fits.getdata(file5_red)

file6_red = dir + 'sheliak_2024-09-23_19-26-59_Red_0317.fits'
science5_red = fits.getdata(file6_red)

file7_red = dir + 'sheliak_2024-09-23_19-27-01_Red_0318.fits'
science6_red = fits.getdata(file7_red)

file8_red = dir + 'sheliak_2024-09-23_19-27-04_Red_0319.fits'
science7_red = fits.getdata(file8_red)

file9_red = dir + 'sheliak_2024-09-23_19-27-07_Red_0320.fits'
science8_red = fits.getdata(file9_red)

file10_red = dir + 'sheliak_2024-09-23_19-27-10_Red_0321.fits'
science9_red = fits.getdata(file10_red)

file11_red = dir + 'sheliak_2024-09-23_19-27-12_Red_0322.fits'
science10_red = fits.getdata(file11_red)

# %%
##312

science_calibrated0=(science0_red-master_bias)/master_flat
#This example needs a mask!
mask=np.zeros(np.shape(science_calibrated0))
for i in range(len(science_calibrated0)):
  for j in range(len(science_calibrated0[i])):
    if master_flat[i][j]<0.2:
      science_calibrated1[i][j]=0
      mask[i][j]=1
mask=mask.astype(bool)

# Criar um objeto FITS a partir dos dados
hdu = fits.PrimaryHDU(science_calibrated0)

# Criar um HDUList (caso queira adicionar extensões)
hdul = fits.HDUList([hdu])

# Salvar a imagem no arquivo .fits
hdul.writeto('sheliak_red_312.fits', overwrite=True)

##313

science_calibrated1=(science1_red-master_bias)/master_flat
#This example needs a mask!
mask=np.zeros(np.shape(science_calibrated1))
for i in range(len(science_calibrated1)):
  for j in range(len(science_calibrated1[i])):
    if master_flat[i][j]<0.2:
      science_calibrated1[i][j]=0
      mask[i][j]=1
mask=mask.astype(bool)

# Criar um objeto FITS a partir dos dados
hdu = fits.PrimaryHDU(science_calibrated1)

# Criar um HDUList (caso queira adicionar extensões)
hdul = fits.HDUList([hdu])

# Salvar a imagem no arquivo .fits
hdul.writeto('sheliak_red_313.fits', overwrite=True)

##314

science_calibrated2=(science2_red-master_bias)/master_flat
#This example needs a mask!
mask=np.zeros(np.shape(science_calibrated2))
for i in range(len(science_calibrated2)):
  for j in range(len(science_calibrated2[i])):
    if master_flat[i][j]<0.2:
      science_calibrated2[i][j]=0
      mask[i][j]=1
mask=mask.astype(bool)

# Criar um objeto FITS a partir dos dados
hdu = fits.PrimaryHDU(science_calibrated2)

# Criar um HDUList (caso queira adicionar extensões)
hdul = fits.HDUList([hdu])

# Salvar a imagem no arquivo .fits
hdul.writeto('sheliak_red_314.fits', overwrite=True)

##315

science_calibrated3=(science3_red-master_bias)/master_flat
#This example needs a mask!
mask=np.zeros(np.shape(science_calibrated3))
for i in range(len(science_calibrated3)):
  for j in range(len(science_calibrated3[i])):
    if master_flat[i][j]<0.2:
      science_calibrated3[i][j]=0
      mask[i][j]=1
mask=mask.astype(bool)

# Criar um objeto FITS a partir dos dados
hdu = fits.PrimaryHDU(science_calibrated3)

# Criar um HDUList (caso queira adicionar extensões)
hdul = fits.HDUList([hdu])

# Salvar a imagem no arquivo .fits
hdul.writeto('sheliak_red_315.fits', overwrite=True)

##316

science_calibrated4=(science4_red-master_bias)/master_flat
#This example needs a mask!
mask=np.zeros(np.shape(science_calibrated4))
for i in range(len(science_calibrated4)):
  for j in range(len(science_calibrated4[i])):
    if master_flat[i][j]<0.2:
      science_calibrated4[i][j]=0
      mask[i][j]=1
mask=mask.astype(bool)

# Criar um objeto FITS a partir dos dados
hdu = fits.PrimaryHDU(science_calibrated4)

# Criar um HDUList (caso queira adicionar extensões)
hdul = fits.HDUList([hdu])

# Salvar a imagem no arquivo .fits
hdul.writeto('sheliak_red_316.fits', overwrite=True)

##317

science_calibrated5=(science5_red-master_bias)/master_flat
#This example needs a mask!
mask=np.zeros(np.shape(science_calibrated5))
for i in range(len(science_calibrated5)):
  for j in range(len(science_calibrated5[i])):
    if master_flat[i][j]<0.2:
      science_calibrated5[i][j]=0
      mask[i][j]=1
mask=mask.astype(bool)

# Criar um objeto FITS a partir dos dados
hdu = fits.PrimaryHDU(science_calibrated5)

# Criar um HDUList (caso queira adicionar extensões)
hdul = fits.HDUList([hdu])

# Salvar a imagem no arquivo .fits
hdul.writeto('sheliak_red_317.fits', overwrite=True)

##318


science_calibrated6=(science6_red-master_bias)/master_flat
#This example needs a mask!
mask=np.zeros(np.shape(science_calibrated6))
for i in range(len(science_calibrated6)):
  for j in range(len(science_calibrated6[i])):
    if master_flat[i][j]<0.2:
      science_calibrated6[i][j]=0
      mask[i][j]=1
mask=mask.astype(bool)

# Criar um objeto FITS a partir dos dados
hdu = fits.PrimaryHDU(science_calibrated6)

# Criar um HDUList (caso queira adicionar extensões)
hdul = fits.HDUList([hdu])

# Salvar a imagem no arquivo .fits
hdul.writeto('sheliak_red_318.fits', overwrite=True)

##319

science_calibrated7=(science7_red-master_bias)/master_flat
#This example needs a mask!
mask=np.zeros(np.shape(science_calibrated7))
for i in range(len(science_calibrated7)):
  for j in range(len(science_calibrated7[i])):
    if master_flat[i][j]<0.2:
      science_calibrated7[i][j]=0
      mask[i][j]=1
mask=mask.astype(bool)

# Criar um objeto FITS a partir dos dados
hdu = fits.PrimaryHDU(science_calibrated7)

# Criar um HDUList (caso queira adicionar extensões)
hdul = fits.HDUList([hdu])

# Salvar a imagem no arquivo .fits
hdul.writeto('sheliak_red_319.fits', overwrite=True)

##320

science_calibrated8=(science8_red-master_bias)/master_flat
#This example needs a mask!
mask=np.zeros(np.shape(science_calibrated8))
for i in range(len(science_calibrated8)):
  for j in range(len(science_calibrated8[i])):
    if master_flat[i][j]<0.2:
      science_calibrated8[i][j]=0
      mask[i][j]=1
mask=mask.astype(bool)

# Criar um objeto FITS a partir dos dados
hdu = fits.PrimaryHDU(science_calibrated8)

# Criar um HDUList (caso queira adicionar extensões)
hdul = fits.HDUList([hdu])

# Salvar a imagem no arquivo .fits
hdul.writeto('sheliak_red_320.fits', overwrite=True)

##321

science_calibrated9=(science9_red-master_bias)/master_flat
#This example needs a mask!
mask=np.zeros(np.shape(science_calibrated9))
for i in range(len(science_calibrated9)):
  for j in range(len(science_calibrated9[i])):
    if master_flat[i][j]<0.2:
      science_calibrated9[i][j]=0
      mask[i][j]=1
mask=mask.astype(bool)

# Criar um objeto FITS a partir dos dados
hdu = fits.PrimaryHDU(science_calibrated9)

# Criar um HDUList (caso queira adicionar extensões)
hdul = fits.HDUList([hdu])

# Salvar a imagem no arquivo .fits
hdul.writeto('sheliak_red_321.fits', overwrite=True)

##322

science_calibrated10=(science10_red-master_bias)/master_flat
#This example needs a mask!
mask=np.zeros(np.shape(science_calibrated10))
for i in range(len(science_calibrated10)):
  for j in range(len(science_calibrated10[i])):
    if master_flat[i][j]<0.2:
      science_calibrated10[i][j]=0
      mask[i][j]=1
mask=mask.astype(bool)

# Criar um objeto FITS a partir dos dados
hdu = fits.PrimaryHDU(science_calibrated10)

# Criar um HDUList (caso queira adicionar extensões)
hdul = fits.HDUList([hdu])

# Salvar a imagem no arquivo .fits
hdul.writeto('sheliak_red_322.fits', overwrite=True)

# %% [markdown]
# ## Plot fits files

# %%
#one plot
lo,up = np.percentile(science_calibrated,5),np.percentile(science_calibrated,95)
plt.figure()
plt.imshow(science_calibrated,cmap='gray',clim=(lo,up))
plt.colorbar()
plt.xlabel('xpix')
plt.ylabel('ypix')
# Out:
# Text(0, 0.5, 'ypix')

# %% [markdown]
# ## Get background and background noise

# %%
# !pip install photutils #only needed if its being run on colabs
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 12.3 MB/s eta 0:00:00
# ...

# %%
from photutils import Background2D,MedianBackground
from astropy.stats import SigmaClip
sigma_clip = SigmaClip(sigma=3.0)
bkg_estimator = MedianBackground()
bkg = Background2D(science_calibrated,(50,50),filter_size=(3,3),sigma_clip=sigma_clip, bkg_estimator=bkg_estimator,coverage_mask=mask)
print("      Median background found: %f, median bkg noise: %f"
      %(bkg.background_median,bkg.background_rms_median)  )
# Out:
# <ipython-input-6-ba4401a7571d>:1: DeprecationWarning: `photutils.Background2D` is a deprecated alias for `photutils.background.Background2D` and will be removed in the future. Instead, please use `from photutils.background import Background2D` to silence this warning.
#   from photutils import Background2D,MedianBackground
# <ipython-input-6-ba4401a7571d>:1: DeprecationWarning: `photutils.MedianBackground` is a deprecated alias for `photutils.background.MedianBackground` and will be removed in the future. Instead, please use `from photutils.background import MedianBackground` to silence this warning.
#   from photutils import Background2D,MedianBackground
#       Median background found: 6.007433, median bkg noise: 6.586666

# %%
fig,ax = plt.subplots(1,3,figsize=(12,6))
lo,up = np.percentile(science_calibrated,1),np.percentile(science_calibrated,99)
ax[0].imshow(science_calibrated,cmap='gray',clim=(lo,up))
lo,up = np.percentile(bkg.background[mask==False],1),np.percentile(bkg.background[mask==False],95)
ax[1].imshow(bkg.background,cmap='gray',clim=(lo,up))
lo,up = np.percentile(science_calibrated-bkg.background,1),np.percentile(science_calibrated-bkg.background,99)
ax[2].imshow(science_calibrated-bkg.background,cmap='gray',clim=(lo,up))

# %%
lo,up = np.percentile(bkg.background_rms[mask==False],1),np.percentile(bkg.background_rms[mask==False],95)
plt.imshow(bkg.background_rms,cmap='gray',clim=(lo,up))
plt.colorbar()
